# %%
import pandas as pd

# %%
df=pd.read_csv("DailyDelhiClimateTest.csv")
df
# Out:
#            date   meantemp   humidity  wind_speed  meanpressure
# 0    2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1    2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2    2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3    2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4    2017-01-05  18.388889  74.944444    3.300000   1014.333333
# ..          ...        ...        ...         ...           ...
# 109  2017-04-20  34.500000  27.500000    5.562500    998.625000
# 110  2017-04-21  34.250000  39.375000    6.962500    999.875000
# 111  2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 112  2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 113  2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [114 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(df['date'],df['meantemp'],color='red')
plt.show()

# %%
x1=df['meantemp'].ewm(alpha=1).mean()
x1
# Out:
# 0      15.913043
# 1      18.500000
# 2      17.111111
# 3      18.700000
# 4      18.388889
#          ...
# 109    34.500000
# 110    34.250000
# 111    32.900000
# 112    32.875000
# 113    32.000000
# Name: meantemp, Length: 114, dtype: float64

# %%
df['ewm']=x1
df
# Out:
#            date   meantemp   humidity  wind_speed  meanpressure        ewm
# 0    2017-01-01  15.913043  85.869565    2.743478     59.000000  15.913043
# 1    2017-01-02  18.500000  77.222222    2.894444   1018.277778  18.500000
# 2    2017-01-03  17.111111  81.888889    4.016667   1018.333333  17.111111
# 3    2017-01-04  18.700000  70.050000    4.545000   1015.700000  18.700000
# 4    2017-01-05  18.388889  74.944444    3.300000   1014.333333  18.388889
# ..          ...        ...        ...         ...           ...        ...
# 109  2017-04-20  34.500000  27.500000    5.562500    998.625000  34.500000
# 110  2017-04-21  34.250000  39.375000    6.962500    999.875000  34.250000
# 111  2017-04-22  32.900000  40.900000    8.890000   1001.600000  32.900000
# 112  2017-04-23  32.875000  27.500000    9.962500   1002.125000  32.875000
# 113  2017-04-24  32.000000  27.142857   12.157143   1004.142857  32.000000
#
# [114 rows x 6 columns]

# %%
plt.scatter(df['date'],df['meantemp'],color="red")
plt.plot(df['date'],x1,color='black',label='alpha=0.9')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 plt.scatter(df['date'],df['meantemp'],color="red")
#       2 plt.plot(df['date'],x1,color='black',label='alpha=0.9')
# ----> 3 plt.legend(color="green")
#       4 plt.show()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\pyplot.py:3384, in legend(*args, **kwargs)
#    3382 @_copy_docstring_and_deprecators(Axes.legend)
#    3383 def legend(*args, **kwargs) -> Legend:
# -> 3384     return gca().legend(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\axes\_axes.py:323, in Axes.legend(self, *args, **kwargs)
#     206 """
#     207 Place a legend on the Axes.
#     208
#    (...)
#     320 .. plot:: gallery/text_labels_and_annotations/legend.py
#     321 """
#     322 handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
# --> 323 self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     324 self.legend_._remove_method = self._remove_legend
#     325 return self.legend_
#
# TypeError: Legend.__init__() got an unexpected keyword argument 'color'
